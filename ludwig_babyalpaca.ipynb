# %% [markdown]
# <a href="https://colab.research.google.com/github/roshanis/ludwig/blob/master/ludwig_babyalpaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Llama2-7b Fine-Tuning with 4bit Quantization
#
# We recommend using a GPU runtime for this example. In the Colab menu bar, choose Runtime > Change Runtime Type and choose GPU under Hardware Accelerator.

# %% [markdown]
# ## Install Ludwig
#
# We'll use the latest version of Ludwig which includes support for quantized fine-tuning.

# %%
# !pip uninstall -y tensorflow --quiet
# !pip install git+https://github.com/roshanis/ludwig
# !pip install accelerate
# !pip install peft
# Out:
# Collecting git+https://github.com/roshanis/ludwig
#   Cloning https://github.com/roshanis/ludwig to /tmp/pip-req-build-clsk54hj
#   Running command git clone --filter=blob:none --quiet https://github.com/roshanis/ludwig /tmp/pip-req-build-clsk54hj
#   Resolved https://github.com/roshanis/ludwig to commit 27338d7448d8db690f8b487d2000683b7172c376
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Cython>=0.25 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (3.0.3)
# Requirement already satisfied: h5py!=3.0.0,>=2.6 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (3.9.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (1.23.5)
# Requirement already satisfied: pandas!=1.1.5,>=1.0 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (1.5.3)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (1.11.3)
# Requirement already satisfied: tabulate>=0.7 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (0.9.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (4.66.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (2.0.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (2.0.2+cu118)
# Requirement already satisfied: torchtext in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (0.15.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (0.15.2+cu118)
# Requirement already satisfied: pydantic<2.0 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (1.10.13)
# Collecting transformers>=4.33.2 (from ludwig==0.8)
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 53.9 MB/s eta 0:00:00
# Collecting tokenizers>=0.13.3 (from ludwig==0.8)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy>=2.3 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (3.6.1)
# Collecting PyYAML!=5.4.*,<6.0.1,>=3.12 (from ludwig==0.8)
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 53.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (1.4.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (1.5.16)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (2.31.0)
# Requirement already satisfied: fsspec[http] in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (2023.6.0)
# Collecting dataclasses-json (from ludwig==0.8)
#   Downloading dataclasses_json-0.6.1-py3-none-any.whl (27 kB)
# Collecting jsonschema<4.7,>=4.5.0 (from ludwig==0.8)
#   Downloading jsonschema-4.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 10.3 MB/s eta 0:00:00
# Collecting marshmallow (from ludwig==0.8)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00
# Collecting marshmallow-jsonschema (from ludwig==0.8)
#   Downloading marshmallow_jsonschema-0.13.0-py3-none-any.whl (11 kB)
# Collecting marshmallow-dataclass==8.5.4 (from ludwig==0.8)
#   Downloading marshmallow_dataclass-8.5.4-py3-none-any.whl (16 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (2.13.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (3.8.1)
# Collecting torchmetrics<=0.11.4,>=0.11.0 (from ludwig==0.8)
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 50.8 MB/s eta 0:00:00
# Collecting torchinfo (from ludwig==0.8)
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (3.12.4)
# Collecting psutil==5.9.4 (from ludwig==0.8)
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 33.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf==3.20.3 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (3.20.3)
# Requirement already satisfied: py-cpuinfo==9.0.0 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (9.0.0)
# Collecting gpustat (from ludwig==0.8)
#   Downloading gpustat-1.1.1.tar.gz (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 13.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting rich~=12.4.4 (from ludwig==0.8)
#   Downloading rich-12.4.4-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.0/232.0 kB 27.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (23.2)
# Collecting retry (from ludwig==0.8)
#   Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Collecting sacremoses (from ludwig==0.8)
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 63.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentencepiece (from ludwig==0.8)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.0 MB/s eta 0:00:00
# Collecting getdaft (from ludwig==0.8)
#   Downloading getdaft-0.1.20-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 76.9 MB/s eta 0:00:00
# Collecting bitsandbytes<0.41.0 (from ludwig==0.8)
#   Downloading bitsandbytes-0.40.2-py3-none-any.whl (92.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 18.1 MB/s eta 0:00:00
# Collecting xlwt (from ludwig==0.8)
#   Downloading xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: xlrd>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (2.0.1)
# Collecting xlsxwriter>=1.4.3 (from ludwig==0.8)
#   Downloading XlsxWriter-3.1.8-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (3.1.2)
# Collecting pyxlsb>=1.0.8 (from ludwig==0.8)
#   Downloading pyxlsb-1.0.10-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (9.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (4.9.3)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (from ludwig==0.8) (1.1)
# Collecting datasets (from ludwig==0.8)
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 51.2 MB/s eta 0:00:00
# Collecting typing-inspect>=0.7.1 (from marshmallow-dataclass==8.5.4->ludwig==0.8)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<4.7,>=4.5.0->ludwig==0.8) (23.1.0)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema<4.7,>=4.5.0->ludwig==0.8)
#   Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=3.0.7->ludwig==0.8) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.1.5,>=1.0->ludwig==0.8) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.1.5,>=1.0->ludwig==0.8) (2023.3.post1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0->ludwig==0.8) (4.5.0)
# Collecting commonmark<0.10.0,>=0.9.0 (from rich~=12.4.4->ludwig==0.8)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from rich~=12.4.4->ludwig==0.8) (2.16.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (6.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3->ludwig==0.8) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ludwig==0.8) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ludwig==0.8) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ludwig==0.8) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ludwig==0.8) (2023.7.22)
# Collecting huggingface_hub<0.18,>=0.16.4 (from tokenizers>=0.13.3->ludwig==0.8)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.2 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->ludwig==0.8) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->ludwig==0.8) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->ludwig==0.8) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->ludwig==0.8) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->ludwig==0.8) (17.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.2->ludwig==0.8) (2023.6.3)
# Collecting safetensors>=0.3.1 (from transformers>=4.33.2->ludwig==0.8)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.9 MB/s eta 0:00:00
# Collecting dill<0.3.8,>=0.3.0 (from datasets->ludwig==0.8)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.4 MB/s eta 0:00:00
# Collecting xxhash (from datasets->ludwig==0.8)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.9 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->ludwig==0.8)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->ludwig==0.8) (3.8.6)
# Collecting loguru (from getdaft->ludwig==0.8)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 8.2 MB/s eta 0:00:00
# Collecting nvidia-ml-py>=11.450.129 (from gpustat->ludwig==0.8)
#   Downloading nvidia_ml_py-12.535.108-py3-none-any.whl (36 kB)
# Collecting blessed>=1.17.1 (from gpustat->ludwig==0.8)
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib->ludwig==0.8) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib->ludwig==0.8) (0.5.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->ludwig==0.8) (8.0.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->ludwig==0.8) (6.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->ludwig==0.8) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->ludwig==0.8) (1.3.2)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.10/dist-packages (from retry->ludwig==0.8) (4.4.2)
# Collecting py<2.0.0,>=1.4.26 (from retry->ludwig==0.8)
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ludwig==0.8) (3.2.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->ludwig==0.8) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->ludwig==0.8) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->ludwig==0.8) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->ludwig==0.8) (3.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->ludwig==0.8) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->ludwig==0.8) (3.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->ludwig==0.8) (0.41.2)
# Requirement already satisfied: torchdata==0.6.1 in /usr/local/lib/python3.10/dist-packages (from torchtext->ludwig==0.8) (0.6.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->ludwig==0.8) (9.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ludwig==0.8) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ludwig==0.8) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ludwig==0.8) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ludwig==0.8) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ludwig==0.8) (1.3.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from blessed>=1.17.1->gpustat->ludwig==0.8) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->ludwig==0.8) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->ludwig==0.8) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->ludwig==0.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->ludwig==0.8) (1.3.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.3->ludwig==0.8) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.3->ludwig==0.8) (0.1.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.7.1->marshmallow-dataclass==8.5.4->ludwig==0.8)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->ludwig==0.8) (2.1.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->ludwig==0.8) (1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->ludwig==0.8) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->ludwig==0.8) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->ludwig==0.8) (3.2.2)
# Building wheels for collected packages: ludwig, gpustat, sacremoses
#   Building wheel for ludwig (pyproject.toml) ... done
#   Created wheel for ludwig: filename=ludwig-0.8-py3-none-any.whl size=1350845 sha256=86b6595e9de0828d6973dfc4191137899998a3bf69763e6723b8836979a6ed19
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kd38uz0q/wheels/96/e6/0b/817559e9f47c07fb653625cd03a846aa896771e176c707f0fa
#   Building wheel for gpustat (pyproject.toml) ... done
#   Created wheel for gpustat: filename=gpustat-1.1.1-py3-none-any.whl size=26534 sha256=a3abf841a381ff9ef6284e01d838a23810b2edd69e1bb08b8f17145738478687
#   Stored in directory: /root/.cache/pip/wheels/ec/d7/80/a71ba3540900e1f276bcae685efd8e590c810d2108b95f1e47
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=e9f8cd1aa1b98a9706de86826e177c1355d1a77a6b79f793c5c136ff97645843
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
# Successfully built ludwig gpustat sacremoses
# Installing collected packages: xlwt, sentencepiece, pyxlsb, nvidia-ml-py, commonmark, bitsandbytes, xxhash, xlsxwriter, torchinfo, safetensors, sacremoses, rich, PyYAML, pyrsistent, py, psutil, mypy-extensions, marshmallow, loguru, dill, blessed, typing-inspect, retry, multiprocess, marshmallow-jsonschema, jsonschema, huggingface_hub, gpustat, tokenizers, marshmallow-dataclass, dataclasses-json, transformers, getdaft, datasets, torchmetrics, ludwig
#   Attempting uninstall: rich
#     Found existing installation: rich 13.6.0
#     Uninstalling rich-13.6.0:
#       Successfully uninstalled rich-13.6.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.19.1
#     Uninstalling jsonschema-4.19.1:
#       Successfully uninstalled jsonschema-4.19.1
# Successfully installed PyYAML-6.0 bitsandbytes-0.40.2 blessed-1.20.0 commonmark-0.9.1 dataclasses-json-0.6.1 datasets-2.14.5 dill-0.3.7 getdaft-0.1.20 gpustat-1.1.1 huggingface_hub-0.17.3 jsonschema-4.6.2 loguru-0.7.2 ludwig-0.8 marshmallow-3.20.1 marshmallow-dataclass-8.5.4 marshmallow-jsonschema-0.13.0 multiprocess-0.70.15 mypy-extensions-1.0.0 nvidia-ml-py-12.535.108 psutil-5.9.4 py-1.11.0 pyrsistent-0.19.3 pyxlsb-1.0.10 retry-0.9.2 rich-12.4.4 sacremoses-0.0.53 safetensors-0.4.0 sentencepiece-0.1.99 tokenizers-0.14.1 torchinfo-1.8.0 torchmetrics-0.11.4 transformers-4.34.0 typing-inspect-0.9.0 xlsxwriter-3.1.8 xlwt-1.3.0 xxhash-3.4.1
# Collecting accelerate
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (17.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.23.0
# Collecting peft
#   Downloading peft-0.5.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft) (6.0)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.0.1+cu118)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft) (4.34.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.66.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from peft) (0.23.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft) (0.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->peft) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->peft) (17.0.2)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->peft) (0.17.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (0.14.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate->peft) (2023.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Installing collected packages: peft
# Successfully installed peft-0.5.0

# %% [markdown]
# ## Set your HuggingFace API Token
#
# Obtain a [HuggingFace API Token](https://huggingface.co/docs/hub/security-tokens) and request access to [Llama2-7b-hf](https://huggingface.co/meta-llama/Llama-2-7b-hf) before proceeding.

# %%
import os

os.environ["HUGGING_FACE_HUB_TOKEN"] = "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"

# %% [markdown]
# ## Configure Model Training
#
# The Ludwig [configuration](https://ludwig.ai/latest/configuration/) specifies the components of the training job including:
#
# - Model type (LLM) and base pretrained model name from HuggingFace
# - Input and output features from the training dataset
# - Quantization (4bit) and parameter-efficient fine-tuning (LoRA)
# - Training hyperparameters (learning rate, batch size, etc.)
# - Preprocessing (e.g., sampling to speed up training)
# - Backend for execution (local, but could also be Ray)

# %%
import yaml

config_str = """
model_type: llm
base_model: meta-llama/Llama-2-7b-hf

quantization:
  bits: 4

adapter:
  type: lora

prompt:
  template: |
    ### Instruction:
    {instruction}

    ### Input:
    {input}

    ### Response:

input_features:
  - name: prompt
    type: text
    preprocessing:
      max_sequence_length: 256

output_features:
  - name: output
    type: text
    preprocessing:
      max_sequence_length: 256

trainer:
  type: finetune
  learning_rate: 0.0001
  batch_size: 1
  gradient_accumulation_steps: 16
  epochs: 3
  learning_rate_scheduler:
    warmup_fraction: 0.01

preprocessing:
  sample_ratio: 0.1
"""

config = yaml.safe_load(config_str)

# %%
# check if babyalpaca is present
import ludwig.datasets
dataset_names = ludwig.datasets.list_datasets()
from ludwig.datasets import babyalpaca

# %% [markdown]
# ## Train!
#
# Start training on your local GPU and monitor progress (including metrics) inline.
#
# In this example, we'll be training on the [Alpaca](https://crfm.stanford.edu/2023/03/13/alpaca.html) dataset to turn Llama2-7b into a rudimentary chatbot. But you can use any dataset to fine-tune for other tasks.

# %%
import logging
from ludwig.api import LudwigModel


model = LudwigModel(config=config, logging_level=logging.INFO)
results = model.train(dataset="ludwig://babyalpaca")
print(results)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# INFO:ludwig.utils.print_utils:
# INFO:ludwig.utils.print_utils:╒════════════════════════╕
# INFO:ludwig.utils.print_utils:│ EXPERIMENT DESCRIPTION │
# INFO:ludwig.utils.print_utils:╘════════════════════════╛
# INFO:ludwig.utils.print_utils:
# INFO:ludwig.api:╒══════════════════╤═════════════════════════════════════════════════════════════════════════════════════════╕
# │ Experiment name  │ api_experiment                                                                          │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┤
# │ Model name       │ run                                                                                     │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┤
# │ Output directory │ /content/results/api_experiment_run                                                     │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┤
# │ ludwig_version   │ '0.8'                                                                                   │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┤
# │ command          │ ('/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py -f '                 │
# │                  │  '/root/.local/share/jupyter/runtime/kernel-de858295-cf9d-441f-9692-91cd68704cd6.json') │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┤
# │ random_seed      │ 42                                                                                      │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┤
# │ dataset          │ 'ludwig://babyalpaca'                                                                   │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┤
# │ data_format      │ 'ludwig'                                                                                │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┤
# │ torch_version    │ '2.0.1+cu118'                                                                           │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┤
# │ compute          │ {   'arch_list': [   'sm_37',                                                           │
# │                  │                      'sm_50',                                                           │
# │                  │                      'sm_60',                                                           │
# │                  │                      'sm_70',                                                           │
# │                  │                      'sm_75',                                                           │
# │                  │                      'sm_80',                                                           │
# │                  │                      'sm_86',                                                           │
# │                  │                      'sm_90'],                                                          │
# │                  │     'devices': {   0: {   'device_capability': (7, 0),                                  │
# │                  │                           'device_properties': "_CudaDeviceProperties(name='Tesla "     │
# │                  │                                                "V100-SXM2-16GB', major=7, "             │
# │                  │                                                'minor=0, total_memory=16150MB, '        │
# │                  │                                                'multi_processor_count=80)',             │
# │                  │                           'gpu_type': 'Tesla V100-SXM2-16GB'}},                         │
# │                  │     'gencode_flags': '-gencode compute=compute_37,code=sm_37 -gencode '                 │
# │                  │                      'compute=compute_50,code=sm_50 -gencode '                          │
# │                  │                      'compute=compute_60,code=sm_60 -gencode '                          │
# │                  │                      'compute=compute_70,code=sm_70 -gencode '                          │
# │                  │                      'compute=compute_75,code=sm_75 -gencode '                          │
# │                  │                      'compute=compute_80,code=sm_80 -gencode '                          │
# │                  │                      'compute=compute_86,code=sm_86 -gencode '                          │
# │                  │                      'compute=compute_90,code=sm_90',                                   │
# │                  │     'gpus_per_node': 1,                                                                 │
# │                  │     'num_nodes': 1}                                                                     │
# ╘══════════════════╧═════════════════════════════════════════════════════════════════════════════════════════╛
# INFO:ludwig.utils.print_utils:
# INFO:ludwig.utils.print_utils:╒═══════════════╕
# INFO:ludwig.utils.print_utils:│ LUDWIG CONFIG │
# INFO:ludwig.utils.print_utils:╘═══════════════╛
# INFO:ludwig.utils.print_utils:
# INFO:ludwig.api:User-specified config (with upgrades):
#
# INFO:ludwig.api:{   'adapter': {'type': 'lora'},
#     'base_model': 'meta-llama/Llama-2-7b-hf',
#     'input_features': [   {   'name': 'prompt',
#                               'preprocessing': {'max_sequence_length': 256},
#                               'type': 'text'}],
#     'ludwig_version': '0.8',
#     'model_type': 'llm',
#     'output_features': [   {   'name': 'output',
#                                'preprocessing': {'max_sequence_length': 256},
#                                'type': 'text'}],
#     'preprocessing': {'sample_ratio': 0.1},
#     'prompt': {   'template': '### Instruction:\n'
#                               '{instruction}\n'
#                               '\n'
#                               '### Input:\n'
#                               '{input}\n'
#                               '\n'
#                               '### Response:\n'},
#     'quantization': {'bits': 4},
#     'trainer': {   'batch_size': 1,
#                    'epochs': 3,
#                    'gradient_accumulation_steps': 16,
#                    'learning_rate': 0.0001,
#                    'learning_rate_scheduler': {'warmup_fraction': 0.01},
#                    'type': 'finetune'}}
# INFO:ludwig.api:
# Full config saved to:
# /content/results/api_experiment_run/api_experiment/model/model_hyperparameters.json
# INFO:ludwig.utils.print_utils:
# INFO:ludwig.utils.print_utils:╒═══════════════╕
# INFO:ludwig.utils.print_utils:│ PREPROCESSING │
# INFO:ludwig.utils.print_utils:╘═══════════════╛
# INFO:ludwig.utils.print_utils:
# babyalpaca.json: 32.0kB [00:00, 91.9kB/s]
# WARNING:ludwig.datasets.loaders.dataset_loader:No sha256 digest provided for dataset babyalpaca, cannot verify.
# INFO:ludwig.datasets.loaders.dataset_loader:Contents:
# INFO:ludwig.datasets.loaders.dataset_loader:    babyalpaca.json: 937c9539addc3b67c554bf0166329ed402a38bb382c2f06eb88b9392d9879faa
# INFO:ludwig.data.preprocessing:No cached dataset found at /content/ludwigbabyalpaca.training.hdf5. Preprocessing the dataset.
# INFO:ludwig.data.preprocessing:Using full dataframe
# INFO:ludwig.data.preprocessing:Building dataset (it may take a while)
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# INFO:ludwig.utils.tokenizers:Loaded HuggingFace implementation of meta-llama/Llama-2-7b-hf tokenizer
# WARNING:ludwig.utils.tokenizers:No padding token id found. Using eos_token as pad_token.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# INFO:ludwig.features.text_feature:Max length of feature 'None': 43 (without start and stop symbols)
# INFO:ludwig.features.text_feature:Setting max length using dataset: 45 (including start and stop symbols)
# INFO:ludwig.features.text_feature:max sequence length is 45 for feature 'None'
# INFO:ludwig.utils.tokenizers:Loaded HuggingFace implementation of meta-llama/Llama-2-7b-hf tokenizer
# WARNING:ludwig.utils.tokenizers:No padding token id found. Using eos_token as pad_token.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# INFO:ludwig.features.text_feature:Max length of feature 'output': 133 (without start and stop symbols)
# INFO:ludwig.features.text_feature:Setting max length using dataset: 135 (including start and stop symbols)
# INFO:ludwig.features.text_feature:max sequence length is 135 for feature 'output'
# INFO:ludwig.utils.tokenizers:Loaded HuggingFace implementation of meta-llama/Llama-2-7b-hf tokenizer
# WARNING:ludwig.utils.tokenizers:No padding token id found. Using eos_token as pad_token.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# INFO:ludwig.utils.tokenizers:Loaded HuggingFace implementation of meta-llama/Llama-2-7b-hf tokenizer
# WARNING:ludwig.utils.tokenizers:No padding token id found. Using eos_token as pad_token.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# INFO:ludwig.data.preprocessing:Building dataset: DONE
# INFO:ludwig.data.cache.manager:Writing preprocessed training set cache to /content/ludwigbabyalpaca.training.hdf5
# INFO:ludwig.data.cache.manager:Writing preprocessed validation set cache to /content/ludwigbabyalpaca.validation.hdf5
# INFO:ludwig.data.cache.manager:Writing preprocessed test set cache to /content/ludwigbabyalpaca.test.hdf5
# INFO:ludwig.data.cache.manager:Writing train set metadata to /content/ludwigbabyalpaca.meta.json
# WARNING:ludwig.data.preprocessing:Validation set empty. If this is unintentional, please check the preprocessing configuration.
# INFO:ludwig.api:
# Dataset Statistics
# INFO:ludwig.api:╒═══════════╤═══════════════╤════════════════════╕
# │ Dataset   │   Size (Rows) │ Size (In Memory)   │
# ╞═══════════╪═══════════════╪════════════════════╡
# │ Training  │             3 │ 848 b              │
# ├───────────┼───────────────┼────────────────────┤
# │ Test      │             3 │ 848 b              │
# ╘═══════════╧═══════════════╧════════════════════╛
# INFO:ludwig.utils.print_utils:
# INFO:ludwig.utils.print_utils:╒═══════╕
# INFO:ludwig.utils.print_utils:│ MODEL │
# INFO:ludwig.utils.print_utils:╘═══════╛
# INFO:ludwig.utils.print_utils:
# INFO:ludwig.api:Warnings and other logs:
# INFO:ludwig.models.llm:Loading large language model...
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# INFO:ludwig.models.llm:Done.
# INFO:ludwig.utils.tokenizers:Loaded HuggingFace implementation of meta-llama/Llama-2-7b-hf tokenizer
# WARNING:ludwig.utils.tokenizers:No padding token id found. Using eos_token as pad_token.
# INFO:ludwig.models.llm:==================================================
# INFO:ludwig.models.llm:Trainable Parameter Summary For Fine-Tuning
# INFO:ludwig.models.llm:Fine-tuning with adapter: lora
# INFO:ludwig.models.llm:==================================================
# INFO:ludwig.utils.print_utils:
# INFO:ludwig.utils.print_utils:╒══════════╕
# INFO:ludwig.utils.print_utils:│ TRAINING │
# INFO:ludwig.utils.print_utils:╘══════════╛
# INFO:ludwig.utils.print_utils:
# trainable params: 4,194,304 || all params: 6,742,609,920 || trainable%: 0.06220594176090199
# INFO:ludwig.trainers.trainer:Creating fresh model training run.
# INFO:ludwig.trainers.trainer:Training for 9 step(s), approximately 3 epoch(s).
# INFO:ludwig.trainers.trainer:Early stopping policy: 5 round(s) of evaluation, or 15 step(s), approximately 5 epoch(s).
#
# INFO:ludwig.trainers.trainer:Starting with step 0, epoch: 0
# Training:  33%|███▎      | 3/9 [00:05<00:08,  1.46s/it, loss=0.168]
# INFO:ludwig.trainers.trainer:
# Running evaluation for step: 3, epoch: 0
# Evaluation test : 100%|██████████| 2/2 [00:01<00:00,  1.95it/s]
# INFO:ludwig.trainers.trainer:Evaluation took 1.5226s
#
# INFO:ludwig.utils.metrics_printed_table:╒═══════════════════════╤════════════╤══════════════╤════════════╕
# │                       │      train │ validation   │       test │
# ╞═══════════════════════╪════════════╪══════════════╪════════════╡
# │ bleu                  │     0.1031 │              │     0.2438 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ char_error_rate       │    10.2308 │              │     0.5322 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ loss                  │     2.6849 │              │     1.3823 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ next_token_perplexity │ 15819.8789 │              │ 17686.6719 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ perplexity            │ 31995.3027 │              │ 32000.2148 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge1_fmeasure       │     0.2963 │              │     0.6129 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge1_precision      │     0.1818 │              │     0.5764 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge1_recall         │     0.8000 │              │     0.6548 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge2_fmeasure       │     0.2400 │              │     0.3350 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge2_precision      │     0.1429 │              │     0.3150 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge2_recall         │     0.7500 │              │     0.3580 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeL_fmeasure       │     0.2963 │              │     0.5698 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeL_precision      │     0.1818 │              │     0.5356 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeL_recall         │     0.8000 │              │     0.6089 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeLsum_fmeasure    │     0.2963 │              │     0.5997 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeLsum_precision   │     0.1818 │              │     0.5637 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeLsum_recall      │     0.8000 │              │     0.6410 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ sequence_accuracy     │     0.0000 │              │     0.0000 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ token_accuracy        │     0.0000 │              │     0.0000 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ word_error_rate       │     3.8000 │              │     0.6211 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ combined_loss         │     2.6849 │              │     1.3823 │
# ╘═══════════════════════╧════════════╧══════════════╧════════════╛
# INFO:ludwig.trainers.trainer:Saving model.
# Training:  67%|██████▋   | 6/9 [00:07<00:02,  1.20it/s, loss=0.102]
# INFO:ludwig.trainers.trainer:
# Running evaluation for step: 6, epoch: 1
# Evaluation test : 100%|██████████| 2/2 [00:01<00:00,  1.97it/s]
# INFO:ludwig.trainers.trainer:Evaluation took 1.4117s
#
# INFO:ludwig.utils.metrics_printed_table:╒═══════════════════════╤════════════╤══════════════╤════════════╕
# │                       │      train │ validation   │       test │
# ╞═══════════════════════╪════════════╪══════════════╪════════════╡
# │ bleu                  │     0.1331 │              │     0.2438 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ char_error_rate       │     0.9010 │              │     0.5322 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ loss                  │     1.6394 │              │     1.3774 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ next_token_perplexity │ 18309.4590 │              │ 17679.3594 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ perplexity            │ 31868.4688 │              │ 32000.2148 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge1_fmeasure       │     0.5195 │              │     0.6129 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge1_precision      │     0.4762 │              │     0.5764 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge1_recall         │     0.5714 │              │     0.6548 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge2_fmeasure       │     0.2667 │              │     0.3350 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge2_precision      │     0.2439 │              │     0.3150 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge2_recall         │     0.2941 │              │     0.3580 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeL_fmeasure       │     0.5195 │              │     0.5698 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeL_precision      │     0.4762 │              │     0.5356 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeL_recall         │     0.5714 │              │     0.6089 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeLsum_fmeasure    │     0.5195 │              │     0.5997 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeLsum_precision   │     0.4762 │              │     0.5637 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeLsum_recall      │     0.5714 │              │     0.6410 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ sequence_accuracy     │     0.0000 │              │     0.0000 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ token_accuracy        │     0.0000 │              │     0.0000 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ word_error_rate       │     0.9118 │              │     0.6211 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ combined_loss         │     1.6394 │              │     1.3774 │
# ╘═══════════════════════╧════════════╧══════════════╧════════════╛
# INFO:ludwig.trainers.trainer:Saving model.
# Training: 100%|██████████| 9/9 [00:09<00:00,  1.47it/s, loss=0.102]
# INFO:ludwig.trainers.trainer:
# Running evaluation for step: 9, epoch: 2
# Evaluation test : 100%|██████████| 2/2 [00:01<00:00,  1.96it/s]
# INFO:ludwig.trainers.trainer:Evaluation took 1.4746s
#
# INFO:ludwig.utils.metrics_printed_table:╒═══════════════════════╤════════════╤══════════════╤════════════╕
# │                       │      train │ validation   │       test │
# ╞═══════════════════════╪════════════╪══════════════╪════════════╡
# │ bleu                  │     0.1267 │              │     0.2438 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ char_error_rate       │     0.9208 │              │     0.5322 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ loss                  │     1.6249 │              │     1.3721 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ next_token_perplexity │ 18274.7793 │              │ 17671.9961 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ perplexity            │ 31867.1602 │              │ 32000.2461 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge1_fmeasure       │     0.4935 │              │     0.6129 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge1_precision      │     0.4524 │              │     0.5764 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge1_recall         │     0.5429 │              │     0.6548 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge2_fmeasure       │     0.2400 │              │     0.3350 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge2_precision      │     0.2195 │              │     0.3150 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rouge2_recall         │     0.2647 │              │     0.3580 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeL_fmeasure       │     0.4935 │              │     0.5698 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeL_precision      │     0.4524 │              │     0.5356 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeL_recall         │     0.5429 │              │     0.6089 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeLsum_fmeasure    │     0.4935 │              │     0.5997 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeLsum_precision   │     0.4524 │              │     0.5637 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ rougeLsum_recall      │     0.5429 │              │     0.6410 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ sequence_accuracy     │     0.0000 │              │     0.0000 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ token_accuracy        │     0.0000 │              │     0.0000 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ word_error_rate       │     0.9412 │              │     0.6211 │
# ├───────────────────────┼────────────┼──────────────┼────────────┤
# │ combined_loss         │     1.6249 │              │     1.3721 │
# ╘═══════════════════════╧════════════╧══════════════╧════════════╛
# INFO:ludwig.trainers.trainer:Saving model.
# Training: 100%|██████████| 9/9 [00:11<00:00,  1.26s/it, loss=0.102]
# INFO:ludwig.utils.print_utils:
# INFO:ludwig.utils.print_utils:╒══════════╕
# INFO:ludwig.utils.print_utils:│ FINISHED │
# INFO:ludwig.utils.print_utils:╘══════════╛
# INFO:ludwig.utils.print_utils:
# TrainingResults(train_stats=TrainingStats(training={'output': {'bleu': [0.10308675467967987, 0.13314853608608246, 0.12671594321727753], 'char_error_rate': [10.230769157409668, 0.9009901285171509, 0.9207921028137207], 'loss': [2.684905529022217, 1.6393955945968628, 1.6248667240142822], 'next_token_perplexity': [15819.87890625, 18309.458984375, 18274.779296875], 'perplexity': [31995.302734375, 31868.46875, 31867.16015625], 'rouge1_fmeasure': [0.29629629850387573, 0.5194805264472961, 0.4935064911842346], 'rouge1_precision': [0.1818181872367859, 0.4761904776096344, 0.4523809552192688], 'rouge1_recall': [0.800000011920929, 0.5714285969734192, 0.5428571701049805], 'rouge2_fmeasure': [0.23999999463558197, 0.2666666805744171, 0.23999999463558197], 'rouge2_precision': [0.1428571492433548, 0.24390244483947754, 0.2195121943950653], 'rouge2_recall': [0.75, 0.29411765933036804, 0.2647058963775635], 'rougeL_fmeasure': [0.29629629850387573, 0.5194805264472961, 0.4935064911842346], 'rougeL_precision': [0.1818181872367859, 0.4761904776096344, 0.4523809552192688], 'rougeL_recall': [0.800000011920929, 0.5714285969734192, 0.5428571701049805], 'rougeLsum_fmeasure': [0.29629629850387573, 0.5194805264472961, 0.4935064911842346], 'rougeLsum_precision': [0.1818181872367859, 0.4761904776096344, 0.4523809552192688], 'rougeLsum_recall': [0.800000011920929, 0.5714285969734192, 0.5428571701049805], 'sequence_accuracy': [0.0, 0.0, 0.0], 'token_accuracy': [0.0, 0.0, 0.0], 'word_error_rate': [3.799999952316284, 0.9117646813392639, 0.9411764740943909]}, 'combined': {'loss': [2.684905529022217, 1.6393955945968628, 1.6248667240142822]}}, validation={}, test={'output': {'bleu': [0.2438100129365921, 0.2438100129365921, 0.2438100129365921], 'char_error_rate': [0.5322112441062927, 0.5322112441062927, 0.5322112441062927], 'loss': [1.3823362588882446, 1.3773996829986572, 1.372102975845337], 'next_token_perplexity': [17686.671875, 17679.359375, 17671.99609375], 'perplexity': [32000.21484375, 32000.21484375, 32000.24609375], 'rouge1_fmeasure': [0.6129187941551208, 0.6129187941551208, 0.6129187941551208], 'rouge1_precision': [0.5764346718788147, 0.5764346718788147, 0.5764346718788147], 'rouge1_recall': [0.654771625995636, 0.654771625995636, 0.654771625995636], 'rouge2_fmeasure': [0.3350135385990143, 0.3350135385990143, 0.3350135385990143], 'rouge2_precision': [0.31497254967689514, 0.31497254967689514, 0.31497254967689514], 'rouge2_recall': [0.3580259084701538, 0.3580259084701538, 0.3580259084701538], 'rougeL_fmeasure': [0.569756269454956, 0.569756269454956, 0.569756269454956], 'rougeL_precision': [0.5356379747390747, 0.5356379747390747, 0.5356379747390747], 'rougeL_recall': [0.6089208722114563, 0.6089208722114563, 0.6089208722114563], 'rougeLsum_fmeasure': [0.5997174382209778, 0.5997174382209778, 0.5997174382209778], 'rougeLsum_precision': [0.5637362599372864, 0.5637362599372864, 0.5637362599372864], 'rougeLsum_recall': [0.641025960445404, 0.641025960445404, 0.641025960445404], 'sequence_accuracy': [0.0, 0.0, 0.0], 'token_accuracy': [0.0, 0.0, 0.0], 'word_error_rate': [0.62109375, 0.62109375, 0.62109375]}, 'combined': {'loss': [1.3823362588882446, 1.3773996829986572, 1.372102975845337]}}, evaluation_frequency=EvaluationFrequency(frequency=1, period='epoch')), preprocessed_data=PreprocessedDataset(training_set=<ludwig.data.dataset.pandas.PandasDataset object at 0x7b9a7f38cca0>, validation_set=None, test_set=<ludwig.data.dataset.pandas.PandasDataset object at 0x7b9a50d55f30>, training_set_metadata={'checksum': 'uAqG3U0v_sUpRihZE72B9A==', 'prompt': {'idx2str': ['▁candid', '▁ou', '▁dét', '玉', 'Attr', '变', '▁Cont', 'legt', 'îne', 'spot', 'atar', 'dirname', '写', 'gate', '▁också', 'pto', 'ement', '▁Kl', '▁filesystem', '▁room', '▁Directory', 'zef', 'ю', '▁Call', '▁instances', 'UT', 'itionally', '▁flow', '▁elections', 'Focus', '▁буде', '▁datab', '▁factor', '▁transport', 'greg', '默', '▁interess', 'ског', '▁candidates', 'apis', '▁Made', '▁św', '▁truly', 'Private', '▁belongs', '▁Пів ...

# %%
# !sudo apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.

# %%
# !huggingface-cli login
# !huggingface-cli repo create babyalpaca_rosh1
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# git version 2.34.1
# git-lfs/3.0.2 (GitHub; linux amd64; go 1.18.1)
#
# You are about to create roshanis/babyalpaca_rosh1
# Proceed? [Y/n] Y
#
# Your repo now lives at:
#   https://huggingface.co/roshanis/babyalpaca_rosh1
#
# You can clone it locally with the command below, and commit/push as usual.
#
#   git clone https://huggingface.co/roshanis/babyalpaca_rosh1

# %%
# !huggingface-cli lfs-enable-largefiles babyalpaca_rosh1
# Out:
# This does not look like a valid git repo.

# %%
# !git lfs install
# !git init
# !git clone https://roshanis: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@huggingface.co/roshanis/babyalpaca_rosh1

# !cd babyalpaca_rosh1
# !git config --global user.email "roshan.venugopal@gmail.com"
# Tip: using the same email than for your huggingface.co account will link your commits to your profile
# !git config --global user.name "Roshan Venugopal"
# !git add . --all
# !git commit -m "first commit"
# Out:
# Git LFS initialized.
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# Cloning into 'babyalpaca_rosh1'...
# remote: Enumerating objects: 3, done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 3
# Unpacking objects: 100% (3/3), 422 bytes | 422.00 KiB/s, done.
# warning: adding embedded git repository: babyalpaca_rosh1
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> babyalpaca_rosh1
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached babyalpaca_rosh1
# hint:
# hint: See "git help submodule" for more information.
# [master (root-commit) 6505dbe] first commit
#  38 files changed, 500738 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/logs/2023.10.13/13.21.02.392796.log
#  create mode 100644 .config/logs/2023.10.13/13.21.27.918226.log
#  create mode 100644 .config/logs/2023.10.13/13.21.36.306373.log
#  create mode 100644 .config/logs/2023.10.13/13.21.43.664795.log
#  create mode 100644 .config/logs/2023.10.13/13.21.52.294344.log
#  create mode 100644 .config/logs/2023.10.13/13.21.53.011048.log
#  create mode 100644 .lock_preprocessing
#  create mode 160000 babyalpaca_rosh1
#  create mode 100644 ludwigbabyalpaca.meta.json
#  create mode 100644 ludwigbabyalpaca.test.hdf5
#  create mode 100644 ludwigbabyalpaca.training.hdf5
#  create mode 100644 ludwigbabyalpaca.validation.hdf5
#  create mode 100644 results/api_experiment_run/description.json
#  create mode 100644 results/api_experiment_run/model/logs/test/events.out.tfevents.1697519900.70ed4e78dd8c.1115.1
#  create mode 100644 results/api_experiment_run/model/logs/training/events.out.tfevents.1697519900.70ed4e78dd8c.1115.0
#  create mode 100644 results/api_experiment_run/model/model_hyperparameters.json
#  create mode 100644 results/api_experiment_run/model/model_weights/README.md
#  create mode 100644 results/api_experiment_run/model/model_weights/adapter_config.json
#  create mode 100644 results/api_experiment_run/model/model_weights/adapter_model.bin
#  create mode 100644 results/api_experiment_run/model/training_checkpoints/best.ckpt
#  create mode 100644 results/api_experiment_run/model/training_checkpoints/latest.ckpt
#  create mode 100644 results/api_experiment_run/model/training_progress.json
#  create mode 100644 results/api_experiment_run/model/training_set_metadata.json
#  create mode 100644 results/api_experiment_run/training_statistics.json
#  create mode 100755 sample_data/README.md
#  create mode 100755 sample_data/anscombe.json
#  create mode 100644 sample_data/california_housing_test.csv
#  create mode 100644 sample_data/california_housing_train.csv
#  create mode 100644 sample_data/mnist_test.csv
#  create mode 100644 sample_data/mnist_train_small.csv

# %%
# !git lfs track "results/api_experiment_run/model/model_weights/adapter_model.bin"
# !git lfs track "results/api_experiment_run/model/training_checkpoints/best.ckpt"
# !git lfs track "sample_data/mnist_test.csv"
# !git lfs track "sample_data/mnist_train_small.csv"
# !git remote add origin https://roshanis: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@huggingface.co/roshanis/babyalpaca_rosh1
# !git lfs push --all origin master
# Out:
# "results/api_experiment_run/model/model_weights/adapter_model.bin" already supported
# "results/api_experiment_run/model/training_checkpoints/best.ckpt" already supported
# "sample_data/mnist_test.csv" already supported
# "sample_data/mnist_train_small.csv" already supported
